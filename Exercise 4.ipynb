# %% [markdown]
# Exercise 4
# Divisors
# Create a program that asks the user for a number and then prints out a list of all the divisors of that number. (If you don’t know what a divisor is, it is a number that divides evenly into another number. For example, 13 is a divisor of 26 because 26 / 13 has no remainder.)

# %% [markdown]
# ----------------------------------------------
# My first answer with incorrect range

# %%
num = int(input("Enter a number: \n"))
x = range(1, 100)
a = []
for i in x:
    if num % i == int():
        a.append(i)
a
# Out:
# Enter a number:
# 555
# [1, 3, 5, 15, 37]

# %%
num = int(input("Enter a number: \n"))
x = range(1, num+1)
a = []
for i in x:
    if num % i == int():
        a.append(i)
a
# Out:
# Enter a number:
# 555
# [1, 3, 5, 15, 37, 111, 185, 555]

# %% [markdown]
# ------------------------------
# The answer

# %%
num = int(input("Please choose a number to divide: "))

listRange = list(range(1,num+1))

divisorList = []

for number in listRange:
    if num % number == 0:
        divisorList.append(number)

print(divisorList)
# Out:
# Please choose a number to divide: 555
# [1, 3, 5, 15, 37, 111, 185, 555]

# %% [markdown]
# Other answer

# %%
num = int(input("Please enter a number for which you want to find all divisors: "))
x = list(range(2,num))

divisorlist = []
for i in x:
    if num%i == 0:
        divisorlist.append(i)
    if len(divisorlist) == 1:
        print("The only divisor for " + str(num) + " is " + str(divisorlist))
    elif len(divisorlist) > 1:
        print("List of divisors for " + str(num) + " are " + str(divisorlist))
    else:
        print("There are no divisors for " + str(num))
# Out:
# Please enter a number for which you want to find all divisors: 555
# There are no divisors for 555
# The only divisor for 555 is [3]
# The only divisor for 555 is [3]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# List of divisors for 555 are [3, 5, 15]
# ...

# %%
num = int(input('Please input a number:'))
divList = []
a = list(range(1, ((num)+1)))
for z in a:
    if num%z==0:
        divList.append(z)
print(str(num)+' is evenly divisble by the following:'+str(divList))
print(str(num)+' has '+str(len(divList))+' divisors.')
# Out:
# Please input a number:555
# 555 is evenly divisble by the following:[1, 3, 5, 15, 37, 111, 185, 555]
# 555 has 8 divisors.
